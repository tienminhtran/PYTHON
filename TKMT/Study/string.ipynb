# %%
s = 'Các chuỗi trong Python là mảng các byte đại diện cho các ký tự unicode'
#in chuỗi s
print(s)
#in ký tự khứ K
print(s[0])
print(s[10])
#in ký tự đầu - cuối
print(s[0],s[-1])
#in theo chủ mục
print(s[:])
print(s[4:9])
print(s[:70])   #in từ đầu đến ký tự thứ 70
print(s[0:])
print(s.split())    #tách chuỗi thành các phần tử trong list

s1 = '        Các hàm cơ bản xử lý String trong Python        '
# MÔT SỐ PHƯƠNG THỨC XỬ LÝ CHUỖI
#strip(): xóa khoảng trắng ở đầu và cuối chuỗi
print(s1.strip())   
print(s1.upper())  #in hoa
print(s1.lower())  #in thường   
print(s1.replace("String ","chuỗi "))  #thay thế chuỗi
k = "cơ bản" in s1  #kiểm tra chuỗi
k1 = "không" not in s1  #kiểm tra chuỗi
k2 = "không" in s1  #kiểm tra chuỗi
print(k)
print(k1)
print(k2)

print(s + s1)
#Chúng ta có thể kết hợp chuỗi và số bằng cách sử dụng hàm format()
age = 36
txt = "My name is John, and I am {}"
print(txt.format(age))


s2 = "viết hoa chữ cái đầu tiên của chuỗi"
print(s2.capitalize())  #viết hoa chữ cái đầu tiên của chuỗi

ho_ten = " Tran MINH  TIEN  "
a = ho_ten.count('', 0, len(ho_ten))
print(a)

str1 = "Vi du ham endswith trong python...test";
suffix = "test";
print (str1.endswith(suffix))
print (str1.endswith(suffix, 20))
suffix = "ham"
print (str1.endswith(suffix, 2, 4))
print (str1.endswith(suffix, 2, 6))

print(str1.find("f")) #tìm vị trí xuất hiện đầu tiên của chuỗi. trả về chỉ mục. KHÔNG TẠO RA LỖI NẾU KHÔNG TÌM THẤY
print(str1.find("ham")) #tìm vị trí xuất hiện đầu tiên của chuỗi. trả về chỉ mục
 
print(str1.index("ham")) #tìm vị trí xuất hiện đầu tiên của chuỗi. trả về chỉ mục
# print(str1.index("q")) #tìm vị trí xuất hiện đầu tiên của chuỗi. trả về chỉ mục
str2 = "est";

print(str2.isalpha()) #trả về True nếu tất cả các ký tự trong chuỗi là chữ cái

str3 = "123456";
print(str3.isdigit()) #trả về True nếu tất cả các ký tự trong chuỗi là chữ số


# Hàm join(seq)
# Nối chuỗi các biểu diễn chuỗi của các phần tử trong dãy seq thành một chuỗi
str4 = "-";
seq = ("a", "b", "c"); # This is sequence of strings.
print (str4.join( seq ))

s5 = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

print(max(s5)) #trả về ký tự có giá trị lớn nhất trong chuỗi
print(min(s5)) #trả về ký tự có giá trị nhỏ nhất trong chuỗi


# Hàm strip([chars])
# Thực hiện cả hai phương thức lstrip() và rstrip() trên chuỗi
s6= "     0000000this is string example....wow!!!0000000            ";
print (s6.strip( ' ' )) 


# Hàm swapcase() chuyển định dạng ASCII của một chuỗi thành chữ hoa thành chữ thường và ngược lại

s7="AaBbCcDdEeFfGgHhIiJjKk"
print(s7.swapcase())
# Hàm title() từng ký tự đầu tiên của mỗi từ trong chuỗi thành chữ hoa
# Trả về một bản sao của chuỗi trong đó tất cả ký tự đầu tiên của tất cả các từ là ở kiểu chữ hoa.
s8="this is string example....wow!!!"
print(s8.title())
# Out:
# Các chuỗi trong Python là mảng các byte đại diện cho các ký tự unicode
# C
# t
# C e
# Các chuỗi trong Python là mảng các byte đại diện cho các ký tự unicode
# chuỗi
# Các chuỗi trong Python là mảng các byte đại diện cho các ký tự unicode
# Các chuỗi trong Python là mảng các byte đại diện cho các ký tự unicode
# ['Các', 'chuỗi', 'trong', 'Python', 'là', 'mảng', 'các', 'byte', 'đại', 'diện', 'cho', 'các', 'ký', 'tự', 'unicode']
# Các hàm cơ bản xử lý String trong Python
#         CÁC HÀM CƠ BẢN XỬ LÝ STRING TRONG PYTHON
#         các hàm cơ bản xử lý string trong python
#         Các hàm cơ bản xử lý chuỗi trong Python
# True
# True
# False
# Các chuỗi trong Python là mảng các byte đại diện cho các ký tự unicode        Các hàm cơ bản xử lý String trong Python
# My name is John, and I am 36
# Viết hoa chữ cái đầu tiên của chuỗi
# 19
# True
# True
# False
# False
# -1
# 6
# 6
# True
# True
# a-b-c
# Z
# A
# 0000000this is string example....wow!!!0000000
# aAbBcCdDeEfFgGhHiIjJkK
# ...
