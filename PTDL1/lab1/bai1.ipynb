# %% [markdown]
# ![z5070357460701_c69218be809322169c961796ec7cf663.jpg](attachment:z5070357460701_c69218be809322169c961796ec7cf663.jpg)

# %%
pi = 2
for i in range(1, 100000):
    pi = pi *( 4 * pow(i,2) / (4 * pow(i,2) - 1) )
print(pi)
# Out:
# 3.141584799578707
