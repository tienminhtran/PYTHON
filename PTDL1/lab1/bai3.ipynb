# %% [markdown]
# ![image.png](attachment:image.png)

# %%
newSum =[10,12,20,22]
sum = 0
for i in newSum:
    sum = sum + i
print(sum)
# Out:
# 64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
newSum =[3,1,2,3]
tich = 1
for i in newSum:
    tich = tich * i
print(tich)
# Out:
# 18

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = [-12,20,-27,20,45,-12,60]
newSet = set()
for i in a:
    if(i not in newSet):
        newSet.add(i)
print(newSet)
# Out:
# {-27, 45, -12, 20, 60}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
newList="The quick brown fox jumps over the lazy dog"
arr = newList.split()
k=3
for i in arr:
    if(len(i)!=k):
        print(i, end=" ")
# Out:
# quick brown jumps over lazy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list1 = [1,2,3,4,5]
lis2 = [6,7,8,9,10]
a=False
for i in list1:
    for j in lis2:
        if(i==j):
            a=True
            break
if(a==True):
    print("True")
else:   
    print("False")
# Out:
# False

# %% [markdown]
# ##cách 2

# %%
list1 = [1,2,3,4,5]
list2 = [5,7,8,9,10]
list3 = [5,6,7,8,9]
def fun(list1,lisst2): 
    for i in list1:
        if(i in list2):
            return True
    return False
print(fun(list1,list2))
print(fun(list1,list3))
# Out:
# True
# True
